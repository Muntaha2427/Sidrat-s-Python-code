# %%
def make_shirt(size='large',message='I Love Python'):
    print(f"The {size} size shirt is with the message: {message}!")
make_shirt()
make_shirt(size='medium')
make_shirt(size='small', message='Type Error!!')
# Out:
# The large size shirt is with the message: I Love Python!
# The medium size shirt is with the message: I Love Python!
# The small size shirt is with the message: Type Error!!!
