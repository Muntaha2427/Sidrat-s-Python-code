# %%
def make_shirt(size,message):
    print(f"The size of my shirt is {size}.")
    print(f"The message printed on it will be : '{message}'")

#possitional arguments
make_shirt('Medium','Syntax Error!')
# Out:
# The size of my shirt is Medium.
# The message printed on it will be : 'Syntax Error!'

# %%
#ekyword arguments
make_shirt(message='Python for AI',size='Medium')
# Out:
# The size of my shirt is Medium.
# The message printed on it will be : 'Python for AI'
