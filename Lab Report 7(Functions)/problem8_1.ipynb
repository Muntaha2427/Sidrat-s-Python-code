# %%
def display_message():
    print("Hello Everyone! Today we will learn the implementation of functions in Python.")
display_message()
# Out:
# Hello Everyone! Today we will learn the implementation of functions in Python.
