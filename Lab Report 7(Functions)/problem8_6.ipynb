# %%
def city_country(city_name,country_name):
    return f"{city_name.title()},{country_name.title()}"
name1=city_country('feni','bangladesh')
print(name1)
name2=city_country('islamabad','pakistan')
print(name2)
name3=city_country('makka','saudi arabia')
print(name3)
# Out:
# Feni,Bangladesh
# Islamabad,Pakistan
# Makka,Saudi Arabia
