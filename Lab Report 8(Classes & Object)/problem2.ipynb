# %%
class Molecules:
    def __init__(self,name,symbol):
        self.name=name
        self.symbol=symbol
molecule1=Molecules("Hydrogen","H")
molecule2=Molecules("Sodium","Na")
print(f"The symbol of {molecule2.name} is {molecule2.symbol}")
# Out:
# The symbol of Sodium is Na
